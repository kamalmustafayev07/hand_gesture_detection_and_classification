# %% [markdown]
# Importing project from GoogleDrive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Installing ultralytics to get YOLO model

# %%
# !pip install -U ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 59.8 MB/s eta 0:00:00
# ...

# %% [markdown]
# Import necessary libraries

# %%
import os
import sys
from ultralytics import YOLO
from tensorflow.keras.models import load_model
from google.colab.patches import cv2_imshow
import cv2

# Add project directory to sys.path if needed
project_dir = '/content/drive/MyDrive/Hand_Gesture_Project'
sys.path.append(project_dir)

# Import the inference function
from utils.inference import infer_hand_gestures
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %% [markdown]
# Load models

# %%
det_model_path = os.path.join(project_dir, 'models/detection/hand_detector_best.pt')
cls_model_path = os.path.join(project_dir, 'models/classification/mobilenetv2_best_added_elvin.keras')

# Load YOLO detection model
det_model = YOLO(det_model_path)

# Load Keras classification model
cls_model = load_model(cls_model_path)

# %% [markdown]
# Test the inference (replace with your test image path)

# %%
image_paths = ['/content/test_image_1.jpg','/content/test_image_2.jpg','/content/test_image_3.jpg','/content/test_image_4.jpg','/content/test_image_5.jpg']
predictions = infer_hand_gestures(image_paths, det_model, cls_model)
# Out:
# Output hidden; open in https://colab.research.google.com to view.
